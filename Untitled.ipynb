# %%
import allsp500

# %%
# %pylab inline
import matplotlib
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# Notes:
# until present with filter at 1.5

# %%
sdf, tickdict = allsp500.main1()
# Out:
# 0
# MOS
# fetched data
# 1
# IR
# fetched data
# 2
# ORLY
# fetched data
# 3
# T
# fetched data
# 4
# ETFC
# fetched data
# 5
# MCD
# fetched data
# 6
# DD
# fetched data
# 7
# COG
# fetched data
# 8
# GAS
# fetched data
# 9
# UNM
# fetched data
# 10
# TGNA
# fetched data
# 11
# PH
# fetched data
# 12
# IPG
# fetched data
# 13
# LEN
# fetched data
# 14
# ESS
# fetched data
# 15
# NAVI
# fetched data
# 16
# ALXN
# fetched data
# 17
# KMX
# fetched data
# 18
# NBL
# fetched data
# 19
# XEC
# fetched data
# 20
# HUM
# fetched data
# 21
# STJ
# fetched data
# 22
# SPG
# fetched data
# 23
# AIV
# fetched data
# 24
# ANTM
# fetched data
# 25
# EBAY
# fetched data
# 26
# BK
# fetched data
# 27
# LB
# fetched data
# 28
# VIAB
# fetched data
# 29
# F
# fetched data
# 30
# BIIB
# fetched data
# 31
# WYN
# fetched data
# 32
# VTR
# fetched data
# 33
# GD
# fetched data
# 34
# TMO
# fetched data
# 35
# TE
# fetched data
# 36
# HOT
# fetched data
# 37
# MRK
# fetched data
# 38
# CAT
# ...

# %%
allsp500.main2(tickdict)
# Out:
# 0
# symbol: HUM:
# return: 1.15283339973
# portfolio ret: 1.15283339973
# 1.15283339973
# 1.15283339973
# 1.15283339973
# 0.27263209340314004
# port sharpe: -2.6679467465383975
# indv drawdown: 0.180139763013
# portfolio dd: 0.180139763013
# portf romad: -4.39841182939
# avg indv dd: 0.180139763013
# avg inv ret: 1.15283339973
# avg indv romad: -4.39841182939
# /Users/liamconnell/Hoth/familyFinance/allsp500.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['stratret'] = data.apply(get_stratret,args = (c,), axis = 1)
# 1
# symbol: UNM:
# return: 0.837294211631
# portfolio ret: 0.995063805683
# 0.837294211631
# 1.03208427324
# 1.03208427324
# 0.31040726674058405
# port sharpe: -2.221574064616624
# indv drawdown: 0.968759105326
# ...

# %%
import imp

# %%
imp.reload(allsp500)
# Out:
# <module 'allsp500' from '/Users/liamconnell/Hoth/familyFinance/allsp500.py'>

# %%
import matplotlib

# %%
matplotlib.
