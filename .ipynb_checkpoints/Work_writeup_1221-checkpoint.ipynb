# %%
import allsp500

# %%
# %pylab inline
import matplotlib
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Just GS

# %% [raw]
# I start by looking just at what I had already for GS. As you can see, results are already good. The problem is that there are large momentary drawdowns and I'm not sure if I calculated volatility correclty. I also have to change how I put on positions so that I can get the trading logic correct.

# %%
tickdict = allsp500.main00()
# Out:
# 0
# WMB
# fetched data
# 1
# VRTX
# failed
# 1
# CCI
# fetched data
# 2
# FCX
# fetched data
# 3
# IPG
# fetched data
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# portfolio ret: 0.852742748732
# portfolio vol: 0.24842518811698402
# port sharpe: 3.43259375265
# portfolio dd: 0.486275987942
# portf romad: 1.75361887051

# %% [markdown]
# This looks exactly like the graph from the r code. Volatility and DD are both very high, but maybe these will be less severe with other symbols added.

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: float64
# portfolio ret: 1.25640977616
# portfolio vol: 0.2776583553864024
# port sharpe: 4.5250205938
# portfolio dd: 1.19231370345
# portf romad: 1.05375772544

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# portfolio ret: -0.127913090729
# portfolio vol: 0.3273560554008084
# port sharpe: -0.390746065696
# portfolio dd: 0.460821072266
# portf romad: -0.277576479089
# /Users/liamconnell/Hoth/familyFinance/allsp500.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['stratret'] = trade_logic(data, c)

# %%
tickdict = allsp500.main00()
# Out:
# 0
# SEE
# fetched data
# 1
# AMZN
# fetched data
# 2
# MNST
# fetched data
# 3
# LOW
# fetched data
# 4
# PRU
# fetched data
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: PRU:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: int64
# portfolio ret: 0
# portfolio vol: 0.0
# port sharpe: nan
# portfolio dd: 0
# portf romad: nan
# 1
# symbol: MNST:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: float64
# portfolio ret: 0.266368381617
# portfolio vol: 0.11112004942993674
# port sharpe: 2.39712259834
# portfolio dd: 0.18874544181
# portf romad: 1.41125729481
# 2
# symbol: LOW:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: int64
# portfolio ret: 0.179158780261
# portfolio vol: 0.0740800329532915
# port sharpe: 2.41844898171
# portfolio dd: 0.113823551797
# portf romad: 1.57400447828
# 3
# symbol: SEE:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: int64
# portfolio ret: 0.134733039929
# portfolio vol: 0.05556002471496837
# port sharpe: 2.42499963995
# portfolio dd: 0.0810010460821
# portf romad: 1.66334938184
# 4
# symbol: AMZN:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: float64
# portfolio ret: 0.263621589619
# portfolio vol: 0.13117645871950856
# port sharpe: 2.00967149283
# portfolio dd: 0.253357524042
# portf romad: 1.04051217984

# %%
plot(tickdict['GS'].resid)

# %%
import imp

# %%
plot(tickdict['GS'].dailyrets)

# %%
imp.reload(allsp500)
# Out:
# <module 'allsp500' from '/Users/liamconnell/Hoth/familyFinance/allsp500.py'>
