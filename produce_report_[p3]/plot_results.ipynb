# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from matplotlib import pyplot as plt
import os
import numpy as np

# %%
ser = pd.Series()
all = pd.Series()
for symbol in os.listdir('../data/junkout/'):
    data = pd.read_pickle(''.join(('../data/junkout/', symbol)))[2011:]
    ser = ser.add(data['stratret'], fill_value=0)
    all = all.add(abs(data['pos']), fill_value=0)
plt.plot(np.cumprod(3*ser/all+1))

# %%
data = pd.read_pickle('../data/junkout/CNX')

# %%
data = pd.read_pickle('../data/junkout/CNX')
plt.plot(np.cumprod(data['stratret']+1))

# %%
ser=pd.Series()
sum(ser.add(data['stratret'], fill_value=0))
# Out:
# -0.2923980641861148

# %%
data.columns
# Out:
# Index(['Adj_Close', 'Close', 'Date', 'High', 'Low', 'Open', 'Symbol', 'Volume',
#        'filtered', 'kal_prediction', 'kal_smooth', 'smooth', 'trend', 'resid',
#        'dailyrets', 'yesteresid', 'residvar', 'stratret', 'pos'],
#       dtype='object')

# %%
plt.plot(all)
