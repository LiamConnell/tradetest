# %%
import allsp500

# %%
# %pylab inline
import matplotlib
import seaborn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Just GS

# %% [raw]
# I start by looking just at what I had already for GS. As you can see, results are already good. The problem is that there are large momentary drawdowns and I'm not sure if I calculated volatility correclty. I also have to change how I put on positions so that I can get the trading logic correct.

# %%
tickdict = allsp500.main00()
# Out:
# 0
# WMB
# fetched data
# 1
# VRTX
# failed
# 1
# CCI
# fetched data
# 2
# FCX
# fetched data
# 3
# IPG
# fetched data
# /Users/liamconnell/anaconda/lib/python3.4/site-packages/bs4/__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# portfolio ret: 0.852742748732
# portfolio vol: 0.24842518811698402
# port sharpe: 3.43259375265
# portfolio dd: 0.486275987942
# portf romad: 1.75361887051

# %% [markdown]
# This looks exactly like the graph from the r code. Volatility and DD are both very high, but maybe these will be less severe with other symbols added.

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# Date
# 2010-05-03    1
# 2010-05-04    1
# 2010-05-05    1
# 2010-05-06    1
# 2010-05-07    1
# Name: stratret, dtype: float64
# portfolio ret: 1.25640977616
# portfolio vol: 0.2776583553864024
# port sharpe: 4.5250205938
# portfolio dd: 1.19231370345
# portf romad: 1.05375772544

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: GS:
# portfolio ret: -0.127913090729
# portfolio vol: 0.3273560554008084
# port sharpe: -0.390746065696
# portfolio dd: 0.460821072266
# portf romad: -0.277576479089
# /Users/liamconnell/Hoth/familyFinance/allsp500.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['stratret'] = trade_logic(data, c)

# %%
tickdict = allsp500.main00(50)
# Out:
# 0
# AAL
# fetched data
# 1
# GGP
# fetched data
# 2
# LLL
# fetched data
# 3
# MS
# fetched data
# 4
# COH
# fetched data
# 5
# EXC
# fetched data
# 6
# MTB
# fetched data
# 7
# ADI
# fetched data
# 8
# ITW
# fetched data
# 9
# MLM
# fetched data
# 10
# MS
# fetched data
# 11
# TRV
# fetched data
# 12
# QCOM
# fetched data
# 13
# CTL
# fetched data
# 14
# CVS
# fetched data
# 15
# VTR
# fetched data
# 16
# C
# fetched data
# 17
# EL
# fetched data
# 18
# FISV
# fetched data
# 19
# MON
# fetched data
# 20
# JEC
# fetched data
# 21
# UA
# fetched data
# failed
# 21
# URBN
# failed
# 21
# NFX
# fetched data
# 22
# EMR
# fetched data
# 23
# APD
# fetched data
# 24
# FAST
# fetched data
# 25
# EQIX
# fetched data
# 26
# SYK
# failed
# 26
# SYK
# failed
# 26
# NAVI
# failed
# 26
# GE
# failed
# 26
# FMC
# failed
# 26
# CNX
# failed
# 26
# D
# failed
# 26
# SRE
# failed
# 26
# KLAC
# failed
# 26
# ACE
# failed
# 26
# LNC
# failed
# 26
# PGR
# failed
# 26
# UAL
# failed
# 26
# EW
# failed
# ...

# %%
allsp500.main3(tickdict)
# Out:
# 0
# symbol: INTU:
# nein!
#
# 0
# symbol: ITW:
# nein!
#
# 0
# symbol: CVS:
# nein!
#
# 0
# symbol: GGP:
# portfolio ret: -0.194083205685
# portfolio vol: 0.457924133233099
# port sharpe: -0.423832664844
# portfolio dd: 0.444255528909
# portf romad: -0.43687290997
# /Users/liamconnell/Hoth/familyFinance/allsp500.py:195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return eqcurve[-2], data['stratret']
# 1
# symbol: TRV:
# nein!
#
# 1
# symbol: MON:
# nein!
#
# 1
# symbol: MS:
# nein!
#
# 1
# symbol: C:
# portfolio ret: -0.129889592527
# portfolio vol: 0.3628472514876048
# port sharpe: -0.357973202206
# portfolio dd: 0.366005623266
# portf romad: -0.354884144587
# 2
# symbol: CTL:
# portfolio ret: -0.111952246755
# portfolio vol: 0.3217565438066739
# ...

# %%
plot(tickdict['GS'].resid)

# %%
import imp

# %%
plot(tickdict['GS'].dailyrets)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-c7d50ea1bd6d> in <module>()
# ----> 1 plot(tickdict['GS'].dailyrets)
#
# KeyError: 'GS'

# %%
imp.reload(allsp500)
# Out:
# <module 'allsp500' from '/Users/liamconnell/Hoth/familyFinance/allsp500.py'>
